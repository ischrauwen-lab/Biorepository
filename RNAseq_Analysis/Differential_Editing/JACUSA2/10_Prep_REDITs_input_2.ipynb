# %% [markdown]
# This is a continuation of Step 9 to format the REDITs input. This script pivots the Edited/Non-edited counts per sample.

# %%
library(tidyr)
library(dplyr)
library(readr)
library(stringr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
#Specify input directories
AG_path <- "/mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/AG"
TC_path <- "/mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/TC"

# %%
#Specify output directories
AG_output_dir <- "/mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/AG/Pivoted"
TC_output_dir <- "/mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/TC/Pivoted"

# %%
process_file <- function(file_path, output_directory) {
  # Extract prefix from the file name
  prefix <- sub("^(.*?)_", "\\1", tools::file_path_sans_ext(basename(file_path)))
  
  # Read the TSV file
  df <- read.table(file_path, header = TRUE, sep = "\t", stringsAsFactors = FALSE)
  df <- df %>%
    select(1, 3, 2, everything())

  cat("Head of the input file", prefix, ":\n")
  print(head(df))

  # Pivot and manipulate the data
  stacked_df <- df %>%
    pivot_longer(
        cols = -ID,  # Specify the columns to pivot
        names_to = "Count_Type",
        values_to = "Counts"
    ) %>%
    mutate(
        Count_Type = rep(c("Edited", "Non_Edited"), length.out = n()),
        ID = factor(ID, levels = unique(ID))
    ) %>%
    arrange(ID, Count_Type)

  
  # Rename the "Counts" column to "Prefix_Counts"
  colnames(stacked_df)[colnames(stacked_df) == "Counts"] <- paste(prefix, "Counts", sep = "_")
  
  # Create the final stacked data frame
  stacked_df <- stacked_df %>%
    mutate(ID___Count_Type = paste(ID, Count_Type, sep = "___")) %>%
    select(ID___Count_Type, everything()) %>%
    select(-c(ID, Count_Type))

  cat("Head of the stacked data frame final", prefix, ":\n")
  print(head(stacked_df))
  
  # Write the result to a TSV file in the output directory
  output_file_path <- file.path(output_directory, paste(prefix, "stacked.tsv", sep = "_"))
  write.table(stacked_df, file = output_file_path, sep = "\t", quote = FALSE, row.names = FALSE)
  # Print a success message
  cat("*Table written successfully to:*", output_file_path, "\n")
  
}

# %%
# List all TSV files in the directory
file_list_AG <- list.files(AG_path, pattern = ".tsv$", full.names = TRUE)
file_list_TC <- list.files(TC_path, pattern = ".tsv$", full.names = TRUE)

# %%
print(file_list_AG)
print(file_list_TC)
# Out:
#  [1] "/mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/AG/Ctrl-01_Edited_And_NonEdited__Counts.tsv"
#  [2] "/mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/AG/Ctrl-02_Edited_And_NonEdited__Counts.tsv"
#  [3] "/mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/AG/Ctrl-03_Edited_And_NonEdited__Counts.tsv"
#  [4] "/mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/AG/Ctrl-04_Edited_And_NonEdited__Counts.tsv"
#  [5] "/mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/AG/Ctrl-05_Edited_And_NonEdited__Counts.tsv"
#  [6] "/mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/AG/Ctrl-06_Edited_And_NonEdited__Counts.tsv"
#  [7] "/mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/AG/NO-01_Edited_And_NonEdited__Counts.tsv"
#  [8] "/mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/AG/NO-02_Edited_And_NonEdited__Counts.tsv"
#  [9] "/mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/AG/NO-03_Edited_And_NonEdited__Counts.tsv"
# [10] "/mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/AG/NO-04_Edited_And_NonEdited__Counts.tsv"
# [11] "/mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/AG/NO-05_Edited_And_NonEdited__Counts.tsv"
# [12] "/mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/AG/NO-06_Edited_And_NonEdited__Counts.tsv"
#  [1] "/mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/TC/Ctrl-01_Edited_And_NonEdited__Counts.tsv"
#  [2] "/mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/TC/Ctrl-02_Edited_And_NonEdited__Counts.tsv"
#  [3] "/mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/TC/Ctrl-03_Edited_And_NonEdited__Counts.tsv"
#  [4] "/mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/TC/Ctrl-04_Edited_And_NonEdited__Counts.tsv"
#  [5] "/mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/TC/Ctrl-05_Edited_And_NonEdited__Counts.tsv"
#  [6] "/mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/TC/Ctrl-06_Edited_And_NonEdited__Counts.tsv"
#  [7] "/mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/TC/NO-01_Edited_And_NonEdited__Counts.tsv"
#  [8] "/mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/TC/NO-02_Edited_And_NonEdited__Counts.tsv"
#  [9] "/mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/TC/NO-03_Edited_And_NonEdited__Counts.tsv"
# [10] "/mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/TC/NO-04_Edited_And_NonEdited__Counts.tsv"
# [11] "/mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/TC/NO-05_Edited_And_NonEdited__Counts.tsv"
# [12] "/mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/TC/NO-06_Edited_And_NonEdited__Counts.tsv"

# %%
# Process each file and store the results in the output directory
lapply(file_list_AG, function(file_path) {
  process_file(file_path, AG_output_dir)
})

lapply(file_list_TC, function(file_path) {
  process_file(file_path, TC_output_dir)
})
# Out:
# Head of the input file Ctrl-01Edited_And_NonEdited__Counts :
#           ID Ctrl.01_Edited Ctrl.01_Nonedited
# 1 1_10023876              9                40
# 2 1_10054490            102               471
# 3 1_10057975             42               155
# 4 1_10313231             12                 1
# 5 1_10314652             29                52
# 6 1_10325782             19                13
# Head of the stacked data frame final Ctrl-01Edited_And_NonEdited__Counts :
# # A tibble: 6 × 2
#   ID___Count_Type         `Ctrl-01Edited_And_NonEdited__Counts_Counts`
#   <chr>                                                          <int>
# 1 1_10023876___Edited                                                9
# 2 1_10023876___Non_Edited                                           40
# 3 1_10054490___Edited                                              102
# 4 1_10054490___Non_Edited                                          471
# 5 1_10057975___Edited                                               42
# 6 1_10057975___Non_Edited                                          155
# *Table written successfully to:* /mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/AG/Pivoted/Ctrl-01Edited_And_NonEdited__Counts_stacked.tsv
# Head of the input file Ctrl-02Edited_And_NonEdited__Counts :
#           ID Ctrl.02_Edited Ctrl.02_Nonedited
# 1 1_10023876              9                54
# 2 1_10054490             19               384
# 3 1_10057975             19               115
# 4 1_10313231             36                 7
# 5 1_10314652             25                48
# 6 1_10325782              6                 5
# Head of the stacked data frame final Ctrl-02Edited_And_NonEdited__Counts :
# # A tibble: 6 × 2
#   ID___Count_Type         `Ctrl-02Edited_And_NonEdited__Counts_Counts`
#   <chr>                                                          <int>
# 1 1_10023876___Edited                                                9
# 2 1_10023876___Non_Edited                                           54
# 3 1_10054490___Edited                                               19
# 4 1_10054490___Non_Edited                                          384
# 5 1_10057975___Edited                                               19
# 6 1_10057975___Non_Edited                                          115
# *Table written successfully to:* /mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/AG/Pivoted/Ctrl-02Edited_And_NonEdited__Counts_stacked.tsv
# Head of the input file Ctrl-03Edited_And_NonEdited__Counts :
#           ID Ctrl.03_Edited Ctrl.03_Nonedited
# 1 1_10023876              8                46
# 2 1_10054490            218               263
# 3 1_10057975             46                84
# 4 1_10313231             20                 8
# 5 1_10314652             21                35
# 6 1_10325782             10                24
# Head of the stacked data frame final Ctrl-03Edited_And_NonEdited__Counts :
# # A tibble: 6 × 2
#   ID___Count_Type         `Ctrl-03Edited_And_NonEdited__Counts_Counts`
#   <chr>                                                          <int>
# 1 1_10023876___Edited                                                8
# 2 1_10023876___Non_Edited                                           46
# 3 1_10054490___Edited                                              218
# 4 1_10054490___Non_Edited                                          263
# 5 1_10057975___Edited                                               46
# 6 1_10057975___Non_Edited                                           84
# *Table written successfully to:* /mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/AG/Pivoted/Ctrl-03Edited_And_NonEdited__Counts_stacked.tsv
# Head of the input file Ctrl-04Edited_And_NonEdited__Counts :
#           ID Ctrl.04_Edited Ctrl.04_Nonedited
# 1 1_10023876             14                68
# 2 1_10054490            232               790
# 3 1_10057975             96               540
# 4 1_10313231             33                 4
# 5 1_10314652             21                30
# 6 1_10325782             21                15
# Head of the stacked data frame final Ctrl-04Edited_And_NonEdited__Counts :
# # A tibble: 6 × 2
#   ID___Count_Type         `Ctrl-04Edited_And_NonEdited__Counts_Counts`
#   <chr>                                                          <int>
# 1 1_10023876___Edited                                               14
# 2 1_10023876___Non_Edited                                           68
# 3 1_10054490___Edited                                              232
# 4 1_10054490___Non_Edited                                          790
# 5 1_10057975___Edited                                               96
# 6 1_10057975___Non_Edited                                          540
# *Table written successfully to:* /mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/AG/Pivoted/Ctrl-04Edited_And_NonEdited__Counts_stacked.tsv
# Head of the input file Ctrl-05Edited_And_NonEdited__Counts :
#           ID Ctrl.05_Edited Ctrl.05_Nonedited
# 1 1_10023876              6                39
# 2 1_10054490            154               726
# 3 1_10057975             85               494
# 4 1_10313231             21                 8
# 5 1_10314652             20                13
# 6 1_10325782             18                26
# Head of the stacked data frame final Ctrl-05Edited_And_NonEdited__Counts :
# # A tibble: 6 × 2
#   ID___Count_Type         `Ctrl-05Edited_And_NonEdited__Counts_Counts`
#   <chr>                                                          <int>
# 1 1_10023876___Edited                                                6
# 2 1_10023876___Non_Edited                                           39
# 3 1_10054490___Edited                                              154
# 4 1_10054490___Non_Edited                                          726
# 5 1_10057975___Edited                                               85
# 6 1_10057975___Non_Edited                                          494
# *Table written successfully to:* /mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/AG/Pivoted/Ctrl-05Edited_And_NonEdited__Counts_stacked.tsv
# Head of the input file Ctrl-06Edited_And_NonEdited__Counts :
#           ID Ctrl.06_Edited Ctrl.06_Nonedited
# 1 1_10023876              1                97
# 2 1_10054490             60              1035
# 3 1_10057975             36               594
# 4 1_10313231             17                 2
# 5 1_10314652             32                28
# 6 1_10325782             17                16
# Head of the stacked data frame final Ctrl-06Edited_And_NonEdited__Counts :
# # A tibble: 6 × 2
#   ID___Count_Type         `Ctrl-06Edited_And_NonEdited__Counts_Counts`
#   <chr>                                                          <int>
# 1 1_10023876___Edited                                                1
# 2 1_10023876___Non_Edited                                           97
# 3 1_10054490___Edited                                               60
# 4 1_10054490___Non_Edited                                         1035
# 5 1_10057975___Edited                                               36
# 6 1_10057975___Non_Edited                                          594
# *Table written successfully to:* /mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/AG/Pivoted/Ctrl-06Edited_And_NonEdited__Counts_stacked.tsv
# Head of the input file NO-01Edited_And_NonEdited__Counts :
#           ID NO.01_Edited NO.01_Nonedited
# 1 1_10023876           17              18
# 2 1_10054490          172             243
# 3 1_10057975           46              92
# 4 1_10313231           10              16
# 5 1_10314652           10              20
# 6 1_10325782            5              16
# Head of the stacked data frame final NO-01Edited_And_NonEdited__Counts :
# # A tibble: 6 × 2
#   ID___Count_Type         `NO-01Edited_And_NonEdited__Counts_Counts`
#   <chr>                                                        <int>
# 1 1_10023876___Edited                                             17
# 2 1_10023876___Non_Edited                                         18
# 3 1_10054490___Edited                                            172
# 4 1_10054490___Non_Edited                                        243
# 5 1_10057975___Edited                                             46
# 6 1_10057975___Non_Edited                                         92
# *Table written successfully to:* /mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/AG/Pivoted/NO-01Edited_And_NonEdited__Counts_stacked.tsv
# Head of the input file NO-02Edited_And_NonEdited__Counts :
#           ID NO.02_Edited NO.02_Nonedited
# 1 1_10023876            6              21
# 2 1_10054490          180             363
# 3 1_10057975           69             147
# 4 1_10313231            6               8
# 5 1_10314652           11              34
# 6 1_10325782            4              13
# Head of the stacked data frame final NO-02Edited_And_NonEdited__Counts :
# # A tibble: 6 × 2
#   ID___Count_Type         `NO-02Edited_And_NonEdited__Counts_Counts`
#   <chr>                                                        <int>
# 1 1_10023876___Edited                                              6
# 2 1_10023876___Non_Edited                                         21
# 3 1_10054490___Edited                                            180
# 4 1_10054490___Non_Edited                                        363
# 5 1_10057975___Edited                                             69
# 6 1_10057975___Non_Edited                                        147
# *Table written successfully to:* /mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/AG/Pivoted/NO-02Edited_And_NonEdited__Counts_stacked.tsv
# Head of the input file NO-03Edited_And_NonEdited__Counts :
#           ID NO.03_Edited NO.03_Nonedited
# 1 1_10023876            6              41
# 2 1_10054490          161             440
# 3 1_10057975           32             129
# 4 1_10313231           15               8
# 5 1_10314652           16              27
# 6 1_10325782            7              10
# Head of the stacked data frame final NO-03Edited_And_NonEdited__Counts :
# # A tibble: 6 × 2
#   ID___Count_Type         `NO-03Edited_And_NonEdited__Counts_Counts`
#   <chr>                                                        <int>
# 1 1_10023876___Edited                                              6
# 2 1_10023876___Non_Edited                                         41
# 3 1_10054490___Edited                                            161
# 4 1_10054490___Non_Edited                                        440
# 5 1_10057975___Edited                                             32
# 6 1_10057975___Non_Edited                                        129
# *Table written successfully to:* /mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/AG/Pivoted/NO-03Edited_And_NonEdited__Counts_stacked.tsv
# Head of the input file NO-04Edited_And_NonEdited__Counts :
#           ID NO.04_Edited NO.04_Nonedited
# 1 1_10023876           18              63
# 2 1_10054490          355             780
# 3 1_10057975          228             461
# 4 1_10313231           18              10
# 5 1_10314652           30              63
# 6 1_10325782           21              11
# Head of the stacked data frame final NO-04Edited_And_NonEdited__Counts :
# # A tibble: 6 × 2
#   ID___Count_Type         `NO-04Edited_And_NonEdited__Counts_Counts`
#   <chr>                                                        <int>
# 1 1_10023876___Edited                                             18
# 2 1_10023876___Non_Edited                                         63
# 3 1_10054490___Edited                                            355
# 4 1_10054490___Non_Edited                                        780
# 5 1_10057975___Edited                                            228
# 6 1_10057975___Non_Edited                                        461
# *Table written successfully to:* /mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/AG/Pivoted/NO-04Edited_And_NonEdited__Counts_stacked.tsv
# Head of the input file NO-05Edited_And_NonEdited__Counts :
#           ID NO.05_Edited NO.05_Nonedited
# 1 1_10023876           11              87
# 2 1_10054490          212            1268
# 3 1_10057975          142             535
# 4 1_10313231           24               9
# 5 1_10314652           67              13
# 6 1_10325782           37               4
# Head of the stacked data frame final NO-05Edited_And_NonEdited__Counts :
# # A tibble: 6 × 2
#   ID___Count_Type         `NO-05Edited_And_NonEdited__Counts_Counts`
#   <chr>                                                        <int>
# 1 1_10023876___Edited                                             11
# 2 1_10023876___Non_Edited                                         87
# 3 1_10054490___Edited                                            212
# 4 1_10054490___Non_Edited                                       1268
# 5 1_10057975___Edited                                            142
# 6 1_10057975___Non_Edited                                        535
# *Table written successfully to:* /mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/AG/Pivoted/NO-05Edited_And_NonEdited__Counts_stacked.tsv
# Head of the input file NO-06Edited_And_NonEdited__Counts :
#           ID NO.06_Edited NO.06_Nonedited
# 1 1_10023876           32              92
# 2 1_10054490          271             707
# 3 1_10057975          178             337
# 4 1_10313231           25              15
# 5 1_10314652           34              28
# 6 1_10325782           39              10
# Head of the stacked data frame final NO-06Edited_And_NonEdited__Counts :
# # A tibble: 6 × 2
#   ID___Count_Type         `NO-06Edited_And_NonEdited__Counts_Counts`
#   <chr>                                                        <int>
# 1 1_10023876___Edited                                             32
# 2 1_10023876___Non_Edited                                         92
# 3 1_10054490___Edited                                            271
# 4 1_10054490___Non_Edited                                        707
# 5 1_10057975___Edited                                            178
# 6 1_10057975___Non_Edited                                        337
# *Table written successfully to:* /mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/AG/Pivoted/NO-06Edited_And_NonEdited__Counts_stacked.tsv
# [[1]]
# NULL
#
# [[2]]
# NULL
#
# [[3]]
# NULL
#
# [[4]]
# NULL
#
# [[5]]
# NULL
#
# [[6]]
# NULL
#
# [[7]]
# NULL
#
# [[8]]
# NULL
#
# [[9]]
# NULL
#
# [[10]]
# NULL
#
# [[11]]
# NULL
#
# [[12]]
# NULL
# Head of the input file Ctrl-01Edited_And_NonEdited__Counts :
#           ID Ctrl.01_Edited Ctrl.01_Nonedited
# 1 1_10067239            151                53
# 2  1_1006825             15                21
# 3 1_10068596             95               159
# 4  1_1009780             23                15
# 5 1_10822937              2                10
# 6 1_10822972              3                10
# Head of the stacked data frame final Ctrl-01Edited_And_NonEdited__Counts :
# # A tibble: 6 × 2
#   ID___Count_Type         `Ctrl-01Edited_And_NonEdited__Counts_Counts`
#   <chr>                                                          <int>
# 1 1_10067239___Edited                                              151
# 2 1_10067239___Non_Edited                                           53
# 3 1_1006825___Edited                                                15
# 4 1_1006825___Non_Edited                                            21
# 5 1_10068596___Edited                                               95
# 6 1_10068596___Non_Edited                                          159
# *Table written successfully to:* /mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/TC/Pivoted/Ctrl-01Edited_And_NonEdited__Counts_stacked.tsv
# Head of the input file Ctrl-02Edited_And_NonEdited__Counts :
#           ID Ctrl.02_Edited Ctrl.02_Nonedited
# 1 1_10067239            107                26
# 2  1_1006825             42                11
# 3 1_10068596             95                93
# 4  1_1009780             22                10
# 5 1_10822937             11                16
# 6 1_10822972             16                14
# Head of the stacked data frame final Ctrl-02Edited_And_NonEdited__Counts :
# # A tibble: 6 × 2
#   ID___Count_Type         `Ctrl-02Edited_And_NonEdited__Counts_Counts`
#   <chr>                                                          <int>
# 1 1_10067239___Edited                                              107
# 2 1_10067239___Non_Edited                                           26
# 3 1_1006825___Edited                                                42
# 4 1_1006825___Non_Edited                                            11
# 5 1_10068596___Edited                                               95
# 6 1_10068596___Non_Edited                                           93
# *Table written successfully to:* /mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/TC/Pivoted/Ctrl-02Edited_And_NonEdited__Counts_stacked.tsv
# Head of the input file Ctrl-03Edited_And_NonEdited__Counts :
#           ID Ctrl.03_Edited Ctrl.03_Nonedited
# 1 1_10067239             44                53
# 2  1_1006825             25                 5
# 3 1_10068596             51               182
# 4  1_1009780              7                22
# 5 1_10822937              7                 3
# 6 1_10822972              9                 2
# Head of the stacked data frame final Ctrl-03Edited_And_NonEdited__Counts :
# # A tibble: 6 × 2
#   ID___Count_Type         `Ctrl-03Edited_And_NonEdited__Counts_Counts`
#   <chr>                                                          <int>
# 1 1_10067239___Edited                                               44
# 2 1_10067239___Non_Edited                                           53
# 3 1_1006825___Edited                                                25
# 4 1_1006825___Non_Edited                                             5
# 5 1_10068596___Edited                                               51
# 6 1_10068596___Non_Edited                                          182
# *Table written successfully to:* /mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/TC/Pivoted/Ctrl-03Edited_And_NonEdited__Counts_stacked.tsv
# Head of the input file Ctrl-04Edited_And_NonEdited__Counts :
#           ID Ctrl.04_Edited Ctrl.04_Nonedited
# 1 1_10067239            195                71
# 2  1_1006825             42                23
# 3 1_10068596            167               241
# 4  1_1009780             17                18
# 5 1_10822937             11                15
# 6 1_10822972             32                 5
# Head of the stacked data frame final Ctrl-04Edited_And_NonEdited__Counts :
# # A tibble: 6 × 2
#   ID___Count_Type         `Ctrl-04Edited_And_NonEdited__Counts_Counts`
#   <chr>                                                          <int>
# 1 1_10067239___Edited                                              195
# 2 1_10067239___Non_Edited                                           71
# 3 1_1006825___Edited                                                42
# 4 1_1006825___Non_Edited                                            23
# 5 1_10068596___Edited                                              167
# 6 1_10068596___Non_Edited                                          241
# *Table written successfully to:* /mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/TC/Pivoted/Ctrl-04Edited_And_NonEdited__Counts_stacked.tsv
# Head of the input file Ctrl-05Edited_And_NonEdited__Counts :
#           ID Ctrl.05_Edited Ctrl.05_Nonedited
# 1 1_10067239            208                56
# 2  1_1006825             36                15
# 3 1_10068596            102               252
# 4  1_1009780             16                 3
# 5 1_10822937              1                25
# 6 1_10822972              4                31
# Head of the stacked data frame final Ctrl-05Edited_And_NonEdited__Counts :
# # A tibble: 6 × 2
#   ID___Count_Type         `Ctrl-05Edited_And_NonEdited__Counts_Counts`
#   <chr>                                                          <int>
# 1 1_10067239___Edited                                              208
# 2 1_10067239___Non_Edited                                           56
# 3 1_1006825___Edited                                                36
# 4 1_1006825___Non_Edited                                            15
# 5 1_10068596___Edited                                              102
# 6 1_10068596___Non_Edited                                          252
# *Table written successfully to:* /mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/TC/Pivoted/Ctrl-05Edited_And_NonEdited__Counts_stacked.tsv
# Head of the input file Ctrl-06Edited_And_NonEdited__Counts :
#           ID Ctrl.06_Edited Ctrl.06_Nonedited
# 1 1_10067239            295                33
# 2  1_1006825             16                 8
# 3 1_10068596            175               304
# 4  1_1009780             47                11
# 5 1_10822937              1                12
# 6 1_10822972              6                17
# Head of the stacked data frame final Ctrl-06Edited_And_NonEdited__Counts :
# # A tibble: 6 × 2
#   ID___Count_Type         `Ctrl-06Edited_And_NonEdited__Counts_Counts`
#   <chr>                                                          <int>
# 1 1_10067239___Edited                                              295
# 2 1_10067239___Non_Edited                                           33
# 3 1_1006825___Edited                                                16
# 4 1_1006825___Non_Edited                                             8
# 5 1_10068596___Edited                                              175
# 6 1_10068596___Non_Edited                                          304
# *Table written successfully to:* /mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/TC/Pivoted/Ctrl-06Edited_And_NonEdited__Counts_stacked.tsv
# Head of the input file NO-01Edited_And_NonEdited__Counts :
#           ID NO.01_Edited NO.01_Nonedited
# 1 1_10067239           62              90
# 2  1_1006825           31               7
# 3 1_10068596           33             130
# 4  1_1009780            8              18
# 5 1_10822937            3              15
# 6 1_10822972           15              10
# Head of the stacked data frame final NO-01Edited_And_NonEdited__Counts :
# # A tibble: 6 × 2
#   ID___Count_Type         `NO-01Edited_And_NonEdited__Counts_Counts`
#   <chr>                                                        <int>
# 1 1_10067239___Edited                                             62
# 2 1_10067239___Non_Edited                                         90
# 3 1_1006825___Edited                                              31
# 4 1_1006825___Non_Edited                                           7
# 5 1_10068596___Edited                                             33
# 6 1_10068596___Non_Edited                                        130
# *Table written successfully to:* /mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/TC/Pivoted/NO-01Edited_And_NonEdited__Counts_stacked.tsv
# Head of the input file NO-02Edited_And_NonEdited__Counts :
#           ID NO.02_Edited NO.02_Nonedited
# 1 1_10067239          106             122
# 2  1_1006825           15              12
# 3 1_10068596           84             175
# 4  1_1009780           11               6
# 5 1_10822937            9               9
# 6 1_10822972           11              10
# Head of the stacked data frame final NO-02Edited_And_NonEdited__Counts :
# # A tibble: 6 × 2
#   ID___Count_Type         `NO-02Edited_And_NonEdited__Counts_Counts`
#   <chr>                                                        <int>
# 1 1_10067239___Edited                                            106
# 2 1_10067239___Non_Edited                                        122
# 3 1_1006825___Edited                                              15
# 4 1_1006825___Non_Edited                                          12
# 5 1_10068596___Edited                                             84
# 6 1_10068596___Non_Edited                                        175
# *Table written successfully to:* /mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/TC/Pivoted/NO-02Edited_And_NonEdited__Counts_stacked.tsv
# Head of the input file NO-03Edited_And_NonEdited__Counts :
#           ID NO.03_Edited NO.03_Nonedited
# 1 1_10067239           93              81
# 2  1_1006825           17               4
# 3 1_10068596           42             185
# 4  1_1009780           15               7
# 5 1_10822937            5              31
# 6 1_10822972           18              28
# Head of the stacked data frame final NO-03Edited_And_NonEdited__Counts :
# # A tibble: 6 × 2
#   ID___Count_Type         `NO-03Edited_And_NonEdited__Counts_Counts`
#   <chr>                                                        <int>
# 1 1_10067239___Edited                                             93
# 2 1_10067239___Non_Edited                                         81
# 3 1_1006825___Edited                                              17
# 4 1_1006825___Non_Edited                                           4
# 5 1_10068596___Edited                                             42
# 6 1_10068596___Non_Edited                                        185
# *Table written successfully to:* /mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/TC/Pivoted/NO-03Edited_And_NonEdited__Counts_stacked.tsv
# Head of the input file NO-04Edited_And_NonEdited__Counts :
#           ID NO.04_Edited NO.04_Nonedited
# 1 1_10067239          184             113
# 2  1_1006825           38              17
# 3 1_10068596          167             350
# 4  1_1009780           25              13
# 5 1_10822937           11              19
# 6 1_10822972           20              18
# Head of the stacked data frame final NO-04Edited_And_NonEdited__Counts :
# # A tibble: 6 × 2
#   ID___Count_Type         `NO-04Edited_And_NonEdited__Counts_Counts`
#   <chr>                                                        <int>
# 1 1_10067239___Edited                                            184
# 2 1_10067239___Non_Edited                                        113
# 3 1_1006825___Edited                                              38
# 4 1_1006825___Non_Edited                                          17
# 5 1_10068596___Edited                                            167
# 6 1_10068596___Non_Edited                                        350
# *Table written successfully to:* /mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/TC/Pivoted/NO-04Edited_And_NonEdited__Counts_stacked.tsv
# Head of the input file NO-05Edited_And_NonEdited__Counts :
#           ID NO.05_Edited NO.05_Nonedited
# 1 1_10067239          241             115
# 2  1_1006825           29              25
# 3 1_10068596            0             583
# 4  1_1009780           44              11
# 5 1_10822937            8              18
# 6 1_10822972            8              16
# Head of the stacked data frame final NO-05Edited_And_NonEdited__Counts :
# # A tibble: 6 × 2
#   ID___Count_Type         `NO-05Edited_And_NonEdited__Counts_Counts`
#   <chr>                                                        <int>
# 1 1_10067239___Edited                                            241
# 2 1_10067239___Non_Edited                                        115
# 3 1_1006825___Edited                                              29
# 4 1_1006825___Non_Edited                                          25
# 5 1_10068596___Edited                                              0
# 6 1_10068596___Non_Edited                                        583
# *Table written successfully to:* /mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/TC/Pivoted/NO-05Edited_And_NonEdited__Counts_stacked.tsv
# Head of the input file NO-06Edited_And_NonEdited__Counts :
#           ID NO.06_Edited NO.06_Nonedited
# 1 1_10067239          161              81
# 2  1_1006825           38               2
# 3 1_10068596           34             407
# 4  1_1009780           18              15
# 5 1_10822937            7              15
# 6 1_10822972           13              12
# Head of the stacked data frame final NO-06Edited_And_NonEdited__Counts :
# # A tibble: 6 × 2
#   ID___Count_Type         `NO-06Edited_And_NonEdited__Counts_Counts`
#   <chr>                                                        <int>
# 1 1_10067239___Edited                                            161
# 2 1_10067239___Non_Edited                                         81
# 3 1_1006825___Edited                                              38
# 4 1_1006825___Non_Edited                                           2
# 5 1_10068596___Edited                                             34
# 6 1_10068596___Non_Edited                                        407
# *Table written successfully to:* /mnt/vast/hpc/csg/hcs2152/ZFR_RNA_Editing/JACUSA2/REDITs/all_dpf/TC/Pivoted/NO-06Edited_And_NonEdited__Counts_stacked.tsv
# [[1]]
# NULL
#
# [[2]]
# NULL
#
# [[3]]
# NULL
#
# [[4]]
# NULL
#
# [[5]]
# NULL
#
# [[6]]
# NULL
#
# [[7]]
# NULL
#
# [[8]]
# NULL
#
# [[9]]
# NULL
#
# [[10]]
# NULL
#
# [[11]]
# NULL
#
# [[12]]
# NULL
